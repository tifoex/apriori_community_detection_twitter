# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

def read_from_drive(filename, filetype='csv'):
    drive.mount('/content/drive')
    path = '/content/drive/MyDrive/' + filename + '.' + filetype
    if filetype == 'csv' or 'arff':
        return pd.read_csv(path,header=None)
    #elif filetype == 'arff':
     #   from scipy.io import arff
      #  data, meta = arff.loadarff(path)
       # return pd.DataFrame(data)
    elif filetype in ['xls', 'xlsx']:
        return pd.read_excel(path)
    elif filetype == 'json':
        return pd.read_json(path)
    elif filetype == 'html':
        return pd.read_html(path)
    elif filetype == 'txt':
        with open(path, 'r') as file:
            return file.read()
    else:
        raise ValueError('Unsupported file type.')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/gender-classifier-DFE-791531.csv', encoding='ISO-8859-1')

# %%
print(df.columns)
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'gender', 'gender:confidence', 'profile_yn',
#        'profile_yn:confidence', 'created', 'description', 'fav_number',
#        'gender_gold', 'link_color', 'name', 'profile_yn_gold', 'profileimage',
#        'retweet_count', 'sidebar_color', 'text', 'tweet_coord', 'tweet_count',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame containing the data
# For example, df = pd.read_csv('your_file.csv')

# Count the number of records for each unique _unit_id
unit_id_counts = df['name'].value_counts()

# Sort the Series in descending order
sorted_unit_id_counts = unit_id_counts.sort_values(ascending=False)

# Display the sorted count of records for each unique _unit_id
print(sorted_unit_id_counts)
# Out:
# TudoSobreQuase    30
# 94heskind         27
# Map_Game          24
# naijama           18
# aSEATaxiCab       15
#                   ..
# donnariguero       1
# lizquenhousing     1
# lq2_camouflage     1
# elunanuv           1
# Gbuschrist         1
# Name: name, Length: 18795, dtype: int64

# %%
import pandas as pd

# Assuming 'df' is your DataFrame containing the data
# For example, df = pd.read_csv('your_file.csv')

# Count the number of records for each unique _unit_id
unit_id_counts = df['name'].value_counts()

# Sort the Series in descending order
sorted_unit_id_counts = unit_id_counts.sort_values(ascending=False)

# Keep only the _unit_ids with count more than 10
filtered_unit_ids = sorted_unit_id_counts[sorted_unit_id_counts > 10]

# Display the filtered count of records for each unique _unit_id
print(filtered_unit_ids)
# Out:
# TudoSobreQuase     30
# 94heskind          27
# Map_Game           24
# naijama            18
# aSEATaxiCab        15
# AmnahThunyan       14
# babeniallniall2    13
# sprinklofstyles    11
# melodisthes        11
# Name: name, dtype: int64

# %% [markdown]
# # another dataset

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# !wget -O twitter_friends.zip "https://www.kaggle.com/datasets/hwassner/TwitterFriends/download?datasetVersionNumber=4"

# Unzip the downloaded file
# !unzip twitter_friends.zip
# Out:
# --2023-07-28 07:02:50--  https://www.kaggle.com/datasets/hwassner/TwitterFriends/download?datasetVersionNumber=4
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fdatasets%2Fhwassner%2FTwitterFriends%2Fversions%2F4%3Fresource%3Ddownload [following]
# --2023-07-28 07:02:51--  https://www.kaggle.com/account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fdatasets%2Fhwassner%2FTwitterFriends%2Fversions%2F4%3Fresource%3Ddownload
# Reusing existing connection to www.kaggle.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘twitter_friends.zip’
#
# ...

# %%
from google.colab import files
files.upload()  # Select and upload the kaggle.json file
# Out:
#      <input type="file" id="files-806148d4-18aa-4d2e-b053-0d1d85ed51c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-806148d4-18aa-4d2e-b053-0d1d85ed51c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d hwassner/TwitterFriends -p /content
# Out:
# ...
#  90% 158M/175M [00:01<00:00, 112MB/s]
# 100% 175M/175M [00:01<00:00, 104MB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/TwitterFriends.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
twitterData = pd.read_csv("/content/data.csv", sep=',(?=\S)', engine='python')

# %%
twitterData.head()
# Out:
#                      id         screenName                   tags  \
# 0          "1969527638"  "LlngoMakeEmCum_"  [ "#nationaldogday" ]
# 1            "51878493"     "_notmichelle"  [ "#nationaldogday" ]
# 2          "1393409100"        "jesseayye"          [ "#narcos" ]
# 3           "232891415"     "MrBrianLloyd"     [ "#gloryoutnow" ]
# 4  "710130422907207680"    "sarahdorat_16"  [ "#nationaldogday" ]
#
#                                               avatar  followersCount  \
# 0  "http://pbs.twimg.com/profile_images/534286217...             319
# 1  "http://pbs.twimg.com/profile_images/761977602...             275
# 2  "http://pbs.twimg.com/profile_images/713282938...             120
# 3  "http://pbs.twimg.com/profile_images/133440668...             492
# 4  "http://pbs.twimg.com/profile_images/767180520...             128
#
#    friendsCount  lang       lastSeen               tweetId  \
# 0           112  "en"  1472271687519  "769310701580083200"
# ...

# %%
twitterData.count()
# Out:
# id                40000
# screenName        40000
# tags              40000
# avatar            40000
# followersCount    40000
# friendsCount      40000
# lang              40000
# lastSeen          40000
# tweetId           40000
# friends           40000
# dtype: int64

# %%
import pandas as pd

# Assuming 'df' is your DataFrame containing the data
# For example, df = pd.read_csv('your_file.csv')
df=twitterData
# Count the number of records for each unique _unit_id
unit_id_counts = df['id'].value_counts()

# Sort the Series in descending order
sorted_unit_id_counts = unit_id_counts.sort_values(ascending=False)

# Keep only the _unit_ids with count more than 10
filtered_unit_ids = sorted_unit_id_counts[sorted_unit_id_counts > 10]

# Display the filtered count of records for each unique _unit_id
print(filtered_unit_ids)
# Out:
# Series([], Name: id, dtype: int64)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame containing the data
# For example, df = pd.read_csv('your_file.csv')

# Count the number of records for each unique _unit_id
unit_id_counts = df['screenName'].value_counts()

# Sort the Series in descending order
sorted_unit_id_counts = unit_id_counts.sort_values(ascending=False)

# Display the sorted count of records for each unique _unit_id
print(sorted_unit_id_counts)
# Out:
# "LlngoMakeEmCum_"    1
# "KLitzau"            1
# "reml_conway"        1
# "jesseayye"          1
# "MrBrianLloyd"       1
#                     ..
# "hendygroup"         1
# "Cardifftweeter"     1
# "adamftsh"           1
# "bieberdestine"      1
# "jessmorris98"       1
# Name: screenName, Length: 40000, dtype: int64

# %% [markdown]
# # another dataset

# %%
from google.colab import files
files.upload()  # Select and upload the kaggle.json file
# Out:
#      <input type="file" id="files-84e7d6cc-180d-4f68-9734-2058a469d463" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84e7d6cc-180d-4f68-9734-2058a469d463">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d wolfram77/graphs-snap-higgs-twitter -p /content
# Out:
# ...
#  90% 108M/120M [00:00<00:00, 233MB/s]
# 100% 120M/120M [00:00<00:00, 216MB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/graphs-snap-higgs-twitter.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
import pandas as pd

# Replace the path with the correct one if needed
file_path = '/content/graph_edges.csv'

# Define column names

# Read the file into a DataFrame
Df = pd.read_csv(file_path)

# Display the DataFrame
Df.head()
# Out:
#       ID1     ID2
# 0  131073   36064
# 1  131073  147897
# 2  131074   50361
# 3  131074  101255
# 4  131075   45262

# %%
import pandas as pd

# Replace the path with the correct one if needed
file_path = '/content/Subgraph.csv'

# Define column names

# Read the file into a DataFrame
DF = pd.read_csv(file_path)

# Display the DataFrame
DF.head()

# %%
Df.count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ID1    167314
# ID2    167314
# dtype: int64

# %% [markdown]
# 223789 213163 1341100972 MT
# 223789 213163 1341100972 RE
# 376989 50329 1341101181 RT
# 26375 168366 1341101183 MT
# 376989 13813 1341101192 RT

# %%
import pandas as pd

# Replace the path with the correct one if needed
file_path = '/content/higgs-activity_time.txt'

# Define column names
columns = ['id1', 'id2', 'timestamp', 'action']

# Read the file into a DataFrame
df = pd.read_csv(file_path, sep=' ', header=None, names=columns)

# Display the DataFrame
df.head()
# Out:
#       id1     id2   timestamp action
# 0  223789  213163  1341100972     MT
# 1  223789  213163  1341100972     RE
# 2  376989   50329  1341101181     RT
# 3   26375  168366  1341101183     MT
# 4  376989   13813  1341101192     RT

# %%
df.count
# Out:
# <bound method DataFrame.count of            id1     id2   timestamp action
# 0       223789  213163  1341100972     MT
# 1       223789  213163  1341100972     RE
# 2       376989   50329  1341101181     RT
# 3        26375  168366  1341101183     MT
# 4       376989   13813  1341101192     RT
# ...        ...     ...         ...    ...
# 563064   97296   15483  1341705530     RE
# 563065   19979   49694  1341705552     MT
# 563066   19979   80429  1341705552     MT
# 563067  178085    1062  1341705574     RT
# 563068   23996     253  1341705593     RT
#
# [563069 rows x 4 columns]>

# %%
import pandas as pd

# Assuming you have already defined Df and df

# Find all unique IDs in Df (ID1 + ID2 set)
unique_ids_set = set(Df['ID1']).union(set(Df['ID2']))

# Filter df to keep only records with valid IDs in id1 or id2
df_filtered = df[df['id1'].isin(unique_ids_set) & df['id2'].isin(unique_ids_set)]

# Display the filtered DataFrame
df_filtered
# Out:
#            id1     id2   timestamp action
# 88      197061  197061  1341106510     MT
# 89      197061  197061  1341106510     RE
# 194     182039   74294  1341113160     MT
# 195     182039   74294  1341113160     RE
# 342     149268  295866  1341124661     MT
# ...        ...     ...         ...    ...
# 562280    5214    5206  1341694055     RT
# 562383   82447    7154  1341694907     MT
# 562417   51328   29542  1341695435     RT
# 562582  358987  358987  1341697672     MT
# 562636  134943  152360  1341698585     MT
#
# [5665 rows x 4 columns]

# %%
len(unique_ids_set)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 35328

# %%
df=df_filtered

# %%
# Function to print a dictionary up to a specified number of records
def print_dictionary(dictionary, limit=100):
    print("{")
    count = 0
    for key, value in dictionary.items():
        if count >= limit:
            break
        print(f"    {key}: {value}")
        count += 1
    print("}")

# %%
# Assuming you have already read the file and have the pandas DataFrame 'df'

# Initialize an empty dictionaries to store the results
MT_dict = {}
RT_dict = {}
RE_dict = {}

# Set the number of records to process before printing the progress
records_to_print = 1000
processed_records = 0
total_records = len(df)

# Loop over the DataFrame
for index, row in df.iterrows():
    if row['action'] == 'MT':
        key = row['id2']
        value = row['id1']

        # Check if the key exists in the dictionary, if not, initialize an empty list
        if key not in MT_dict:
            MT_dict[key] = []

        # Append the value to the list
        MT_dict[key].append(value)
    if row['action'] == 'RT':
        key = row['id2']
        value = row['id1']

        # Check if the key exists in the dictionary, if not, initialize an empty list
        if key not in RT_dict:
            RT_dict[key] = []

        # Append the value to the list
        RT_dict[key].append(value)
    if row['action'] == 'RE':
        key = row['id2']
        value = row['id1']

        # Check if the key exists in the dictionary, if not, initialize an empty list
        if key not in RE_dict:
            RE_dict[key] = []

        # Append the value to the list
        RE_dict[key].append(value)

    processed_records += 1
    if processed_records % records_to_print == 0 or processed_records == total_records:
        percentage_complete = (processed_records / total_records) * 100
        print(f'\rProgress: {percentage_complete:.2f}%  ', end='')

# Assuming you have already created the dictionaries MT_dict, RT_dict, and RE_dict


# Print the first 100 records of each dictionary
print("MT_dict:")
print_dictionary(MT_dict, limit=10)

print("\nRT_dict:")
print_dictionary(RT_dict, limit=10)

print("\nRE_dict:")
print_dictionary(RE_dict, limit=10)

# %%
# Assuming you have already created the dictionaries MT_dict, RT_dict, and RE_dict

# Create a new dictionary to store the merged and summed values
merged_dict = {}

# Function to add a prefix to values in a dictionary and merge it with another dictionary
def merge_and_prefix(source_dict, prefix):
    for key, value in source_dict.items():
        if key in merged_dict:
            merged_dict[key] += f"{prefix}-{value}"
        else:
            merged_dict[key] = f"{prefix}-{value}"

# Merge and prefix values from MT_dict
merge_and_prefix(MT_dict, "MT")

# Merge and prefix values from RT_dict
merge_and_prefix(RT_dict, "RT")

# Merge and prefix values from RE_dict
merge_and_prefix(RE_dict, "RE")

# Display the merged dictionary
print("\nmerged_dict:")
print_dictionary(merged_dict, limit=10)

# %% [markdown]
# #here

# %%
# Assuming you have already read the file and have the pandas DataFrame 'df'

# Initialize the dictionaries to store the results
MT_dict = {}
RT_dict = {}
RE_dict = {}
merged_dict = {}
total_dict = {}

# Set the number of records to process before printing the progress
records_to_print = 1000
processed_records = 0
total_records = len(df)

# Loop over the DataFrame
for index, row in df.iterrows():
    if row['action'] == 'MT':
        key = row['id2']
        value = row['id1']

        # Check if the key exists in the dictionary, if not, initialize an empty list
        if key not in MT_dict:
            MT_dict[key] = []

        # Append the value to the list
        MT_dict[key].append(value)

        # Update the merged dictionary with the value and prefix
        if key not in merged_dict:
            merged_dict[key] =[]

        merged_dict[key].append(f"MT-{value}")
        if key not in total_dict:
            total_dict[key] =[]

        total_dict[key].append(value)
    elif row['action'] == 'RT':
        key = row['id2']
        value = row['id1']

        # Check if the key exists in the dictionary, if not, initialize an empty list
        if key not in RT_dict:
            RT_dict[key] = []

        # Append the value to the list
        RT_dict[key].append(value)

        # Update the merged dictionary with the value and prefix
        if key not in merged_dict:
            merged_dict[key] =[]
        merged_dict[key].append(f"RT-{value}")
        if key not in total_dict:
            total_dict[key] =[]

        total_dict[key].append(value)
    elif row['action'] == 'RE':
        key = row['id2']
        value = row['id1']

        # Check if the key exists in the dictionary, if not, initialize an empty list
        if key not in RE_dict:
            RE_dict[key] = []

        # Append the value to the list
        RE_dict[key].append(value)

        # Update the merged dictionary with the value and prefix
        if key not in merged_dict:
            merged_dict[key] =[]
        merged_dict[key].append(f"RE-{value}")
        if key not in total_dict:
            total_dict[key] =[]

        total_dict[key].append(value)

    processed_records += 1
    if processed_records % records_to_print == 0 or processed_records == total_records:
        percentage_complete = (processed_records / total_records) * 100
        print(f'\rProgress: {percentage_complete:.2f}%  ', end='')

# Display the merged dictionary
print("\nMerged Dictionary:")
print_dictionary(merged_dict, limit=10)
print("\nTotal Dictionary:")
print_dictionary(total_dict, limit=10)
# Out:
# Progress: 100.00%
# Merged Dictionary:
# {
#     197061: ['MT-197061', 'RE-197061', 'MT-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061', 'MT-197061', 'RE-197061']
#     74294: ['MT-182039', 'RE-182039']
#     295866: ['MT-149268', 'RE-149268']
#     149268: ['MT-295866', 'RE-295866']
#     173141: ['RT-95728', 'MT-86203', 'RE-86203']
# ...

# %%
# !pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# Assuming you have already created the merged_dict
# Convert the merged_dict to a list of lists (transactions)
transactions = list(total_dict.values())

# Initialize the TransactionEncoder
te = TransactionEncoder()
# Fit and transform the transactions using the TransactionEncoder
te_ary = te.fit(transactions).transform(transactions)
# Convert the transformed array back to a DataFrame
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.2, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.1, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.05, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.005, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.001, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support  itemsets
# 0  0.001167     (492)
# 1  0.001000   (26158)
# 2  0.001134   (27705)
# 3  0.002301   (38535)
# 4  0.001000   (64911)
# 5  0.001384   (81405)
# 6  0.002834   (89805)
# 7  0.001534  (181190)

# %%
# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.0005, use_colnames=True)

# Print the frequent itemsets
print(frequent_itemsets)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support         itemsets
# 0    0.001167            (492)
# 1    0.000684            (511)
# 2    0.000984           (1276)
# 3    0.000667           (2237)
# 4    0.000584           (3547)
# ..        ...              ...
# 122  0.000534   (89805, 26158)
# 123  0.000567   (35729, 89805)
# 124  0.000617   (89805, 64911)
# 125  0.000517  (89805, 110903)
# 126  0.000500  (206362, 89805)
#
# [127 rows x 2 columns]

# %% [markdown]
# # dont run this code

# %%
import pandas as pd

# Assuming you have already created the merged_dict
# Convert the merged_dict to a DataFrame
#df_list = list(merged_dict.items())
#Df = pd.DataFrame.from_dict(dict(df_list), orient='index')
Df = pd.DataFrame.from_dict(merged_dict, orient='index')

# Reset the index and set the column names
Df.reset_index(inplace=True)

# Display the new DataFrame
Df.head()

# %%
import pandas as pd

# Assuming you have already created the merged_dict
# Initialize an empty list to store the dictionaries for each row
data = []

# Loop over the merged_dict and create a dictionary for each row
for key, value_list in merged_dict.items():
    # Create a new dictionary for each row
    row_dict = {'Transaction': key}
    for i, item in enumerate(value_list):
        # Add each item as a separate column
        row_dict[f'Item{i+1}'] = item
    # Append the row dictionary to the data list
    data.append(row_dict)

# Create the DataFrame from the list of dictionaries
Df = pd.DataFrame(data)

# Display the new DataFrame
print(Df)

# %%
import pandas as pd

# Assuming you have already created the merged_dict
# Define the batch size (adjust as needed based on your available memory)
batch_size = 1000

# Generator function to yield batches of rows from the merged_dict
def batch_generator(merged_dict, batch_size):
    keys = iter(merged_dict)
    while True:
        batch = []
        try:
            for _ in range(batch_size):
                key = next(keys)
                value_list = merged_dict[key]
                row_dict = {'Transaction': key}
                for i, item in enumerate(value_list):
                    row_dict[f'Item{i+1}'] = item
                batch.append(row_dict)
        except StopIteration:
            break
        yield batch

# Initialize an empty list to store the batches of DataFrames
data_frames = []

# Generate batches of rows using the generator function
for batch in batch_generator(merged_dict, batch_size):
    data_frames.append(pd.DataFrame(batch))

# Concatenate the list of DataFrames into the final DataFrame
Df = pd.concat(data_frames, ignore_index=True)

# Display the new DataFrame
print(Df)

# %%
class Arules:
    def __init__(self):
        self.repetition = {}
        self.indexes = {}
        self.transactions = None
        self.data = None
        self.frequent_itemsets = None

    def get_frequent_item_sets(self, min_support, transactions=None):
        if self.frequent_itemsets:
            return self.frequent_itemsets
        if not self.transactions:
            self.transactions = transactions
        frequent_item_sets = []
        self.data = self.transactions.T.apply(lambda x: x.dropna().tolist()).tolist()
        unique_items = []
        for i in data:
            for q in i:
                if q not in unique_items:
                    unique_items.append(q)
        for item in unique_items:
            temp = self.transactions[self.transactions.isin([item]).any(axis=1)]
            self.repetition[item] = len(temp)
            self.indexes[item] = set(temp.index.tolist())

        first_frequent_item_sets = [[i[0]] for i in self.repetition.items() if i[1] >= min_support * len(self.transactions)]
        k_minus_1_freq_items = copy.deepcopy(first_frequent_item_sets)
        while True:
            kth_candidates = self.gen_next_candidates(k_minus_1_freq_items)
            kth_candidates_freqs = [0 for i in range(len(kth_candidates))]

            for i in range(len(kth_candidates)):
                intersected_indexes = None
                for item in kth_candidates[i]:
                    indexes = self.indexes[item]
                    if intersected_indexes is None:
                        intersected_indexes = indexes
                    intersected_indexes = intersected_indexes.intersection(indexes)
                kth_candidates_freqs[i] += len(intersected_indexes)

            for i in range (len(kth_candidates_freqs) - 1, -1, -1):
                if kth_candidates_freqs[i] < math.ceil(len(transactions) * min_support):
                    del kth_candidates[i]

            k_minus_1_freq_items = copy.deepcopy(kth_candidates)
            frequent_item_sets.extend(k_minus_1_freq_items)
            if len(kth_candidates) == 0:
                break
        self.frequent_itemsets = frequent_item_sets
        return frequent_item_sets
    def gen_next_candidates(self, k_minus_1_freq_items):
        new_candidates = []
        for p in k_minus_1_freq_items:
            for q in k_minus_1_freq_items:
                if self.can_join(p, q):
                    new_candidate = copy.deepcopy(p)
                    new_candidate.append(q[-1])
                    if not self.has_infrequent_subset(new_candidate, k_minus_1_freq_items):
                        new_candidates.append(new_candidate)
        return new_candidates

    def can_join(self, a, b):
        if len(a) != len(b):
            return False
        k = len(a)
        for i in range(k - 1):
            if a[i] != b[i]:
                return False
        if a[k - 1] >= b[k - 1]:
            return False
        return True


    def has_infrequent_subset(self, candidate, k_minus_1_freq_items):
        k_minus_1_combs = list(combinations(candidate, len(candidate) - 1))
        for combination in k_minus_1_combs:
            found = False
            for itemset in k_minus_1_freq_items:
                if sorted(combination) == sorted(itemset):
                    found = True
            if not found:
                return True
        return False

    def get_arules(self, transactions=None, min_support=None, min_confidence=None, min_lift=None, sort_by="lift"):
        freq_item_sets = self.get_frequent_item_sets(min_support= min_support, transactions=transactions)

        rules = []
        for freq_item_set in freq_item_sets:
            for subset_length in range(1, len(freq_item_set)):
                for subset in combinations(freq_item_set, subset_length):
                    left = copy.deepcopy(subset)
                    right = list(set(freq_item_set) - set(subset))
                    confidence = 0
                    if self.calc_support(subset) == 0:
                        continue
                    confidence = self.calc_support(freq_item_set) / self.calc_support(subset)
                    if self.calc_support(right) == 0:
                        continue
                    lift = confidence / self.calc_support(right)
                    support = self.calc_support(freq_item_set)

                    if confidence >= min_confidence and (min_lift is None or lift >= min_lift):
                        rule = {}
                        rule['left'] = left
                        rule['right'] = right
                        rule['confidence'] = confidence
                        rule['support'] = support
                        rule['lift'] = lift
                        rules.append(rule)

        sorted_rules = sorted(rules, key=lambda k: k[sort_by], reverse=True)
        return sorted_rules

    def calc_support(self, itemset):
        support = 0
        intersected_indexes = None
        for item in itemset:
            indexes = self.indexes[item]
            if intersected_indexes is None:
                intersected_indexes = indexes
            intersected_indexes = intersected_indexes.intersection(indexes)
        return len(intersected_indexes) / len(self.transactions)


    def print_rules(self, rules):
        for rule in rules:
            print(str(list(rule['left'])) + " ==> " + str(rule['right']))
            print("\tsupport: " + str(rule['support']))
            print("\tconfidence: " + str(rule['confidence']))
            print("\tlift: " + str(rule['lift']))
            print("-" * 50)
    def count_item(self, items: list):
        ans = 0
        for i in self.data:
            if set(items).issubset(set(i)):
                ans += 1
        return ans
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
min_support = 0.005
arules = Arules()
fis = arules.get_frequent_item_sets(min_support,transactions)
len(fis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-cfc7e4c6122d> in <cell line: 3>()
#       1 min_support = 0.005
#       2 arules = Arules()
# ----> 3 fis = arules.get_frequent_item_sets(min_support,transactions)
#       4 len(fis)
#
# <ipython-input-6-badb85274678> in get_frequent_item_sets(self, min_support, transactions)
#      13             self.transactions = transactions
#      14         frequent_item_sets = []
# ...

# %%
import pandas as pd
import copy
import math
from itertools import combinations

class Arules:
    def __init__(self):
        self.repetition = {}
        self.indexes = {}
        self.transactions = None
        self.data = None
        self.frequent_itemsets = None

    def get_frequent_item_sets(self, min_support, transactions=None):
        if self.frequent_itemsets:
            return self.frequent_itemsets
        if not self.transactions:
            self.transactions = transactions
        frequent_item_sets = []
        self.data = [list(filter(None, transaction)) for transaction in self.transactions]
        unique_items = []
        for i in self.data:
            for q in i:
                if q not in unique_items:
                    unique_items.append(q)
        for item in unique_items:
            temp = self.transactions[self.transactions.isin([item]).any(axis=1)]
            self.repetition[item] = len(temp)
            self.indexes[item] = set(temp.index.tolist())

        first_frequent_item_sets = [[i[0]] for i in self.repetition.items() if i[1] >= min_support * len(self.transactions)]
        k_minus_1_freq_items = copy.deepcopy(first_frequent_item_sets)
        while True:
            kth_candidates = self.gen_next_candidates(k_minus_1_freq_items)
            kth_candidates_freqs = [0 for i in range(len(kth_candidates))]

            for i in range(len(kth_candidates)):
                intersected_indexes = None
                for item in kth_candidates[i]:
                    indexes = self.indexes[item]
                    if intersected_indexes is None:
                        intersected_indexes = indexes
                    intersected_indexes = intersected_indexes.intersection(indexes)
                kth_candidates_freqs[i] += len(intersected_indexes)

            for i in range(len(kth_candidates_freqs) - 1, -1, -1):
                if kth_candidates_freqs[i] < math.ceil(len(transactions) * min_support):
                    del kth_candidates[i]

            k_minus_1_freq_items = copy.deepcopy(kth_candidates)
            frequent_item_sets.extend(k_minus_1_freq_items)
            if len(kth_candidates) == 0:
                break
        self.frequent_itemsets = frequent_item_sets
        return frequent_item_sets

    def gen_next_candidates(self, k_minus_1_freq_items):
        new_candidates = []
        for p in k_minus_1_freq_items:
            for q in k_minus_1_freq_items:
                if self.can_join(p, q):
                    new_candidate = copy.deepcopy(p)
                    new_candidate.append(q[-1])
                    if not self.has_infrequent_subset(new_candidate, k_minus_1_freq_items):
                        new_candidates.append(new_candidate)
        return new_candidates

    def can_join(self, a, b):
        if len(a) != len(b):
            return False
        k = len(a)
        for i in range(k - 1):
            if a[i] != b[i]:
                return False
        if a[k - 1] >= b[k - 1]:
            return False
        return True

    def has_infrequent_subset(self, candidate, k_minus_1_freq_items):
        k_minus_1_combs = list(combinations(candidate, len(candidate) - 1))
        for combination in k_minus_1_combs:
            found = False
            for itemset in k_minus_1_freq_items:
                if sorted(combination) == sorted(itemset):
                    found = True
            if not found:
                return True
        return False

    def get_arules(self, transactions=None, min_support=None, min_confidence=None, min_lift=None, sort_by="lift"):
        freq_item_sets = self.get_frequent_item_sets(min_support=min_support, transactions=transactions)

        rules = []
        for freq_item_set in freq_item_sets:
            for subset_length in range(1, len(freq_item_set)):
                for subset in combinations(freq_item_set, subset_length):
                    left = copy.deepcopy(subset)
                    right = list(set(freq_item_set) - set(subset))
                    confidence = 0
                    if self.calc_support(subset) == 0:
                        continue
                    confidence = self.calc_support(freq_item_set) / self.calc_support(subset)
                    if self.calc_support(right) == 0:
                        continue
                    lift = confidence / self.calc_support(right)
                    support = self.calc_support(freq_item_set)

                    if confidence >= min_confidence and (min_lift is None or lift >= min_lift):
                        rule = {}
                        rule['left'] = left
                        rule['right'] = right
                        rule['confidence'] = confidence
                        rule['support'] = support
                        rule['lift'] = lift
                        rules.append(rule)

        sorted_rules = sorted(rules, key=lambda k: k[sort_by], reverse=True)
        return sorted_rules

    def calc_support(self, itemset):
        support = 0
        intersected_indexes = None
        for item in itemset:
            indexes = self.indexes[item]
            if intersected_indexes is None:
                intersected_indexes = indexes
            intersected_indexes = intersected_indexes.intersection(indexes)
        return len(intersected_indexes) / len(self.transactions)

    def print_rules(self, rules):
        for rule in rules:
            print(str(list(rule['left'])) + " ==> " + str(rule['right']))
            print("\tsupport: " + str(rule['support']))
            print("\tconfidence: " + str(rule['confidence']))
            print("\tlift: " + str(rule['lift']))
            print("-" * 50)

    def count_item(self, items: list):
        ans = 0
        for i in self.data:
            if set(items).issubset(set(i)):
                ans += 1
        return ans
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
min_support = 0.001
arules = Arules()
fis = arules.get_frequent_item_sets(min_support,transactions)
len(fis)

# %%
fis_numbered = []
for i in fis:
    fis_numbered.append((arules.count_item(i), i))
fis_numbered.sort(reverse=True)
print("10 Most Repeated Sets:")
for i, item in enumerate(fis_numbered[:10], 1):
    print("{:2}- frequency: {} items: [{}]".format(i, item[0], ", ".join(["{:18}".format('"' + j + '"') for j in item[1]])))

# %% [markdown]
# # run this instead

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# Assuming you have already created the merged_dict
# Convert the merged_dict to a list of lists (transactions)
transactions = list(total_dict.values())

# Initialize the TransactionEncoder
te = TransactionEncoder()
# Fit and transform the transactions using the TransactionEncoder
te_ary = te.fit(transactions).transform(transactions)
# Convert the transformed array back to a DataFrame
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm to calculate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.0005, use_colnames=True)

# Extract the item and its support value from the frequent itemsets DataFrame
frequent_items_with_support = frequent_itemsets[['itemsets', 'support']]

# Sort the frequent items by support in descending order
frequent_items_with_support = frequent_items_with_support.sort_values(by='support', ascending=False)

# Display the frequent items along with their support values (sorted by support)
frequent_items_with_support
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             itemsets   support
# 81           (89805)  0.002834
# 47           (38535)  0.002301
# 106         (181190)  0.001534
# 79           (81405)  0.001384
# 0              (492)  0.001167
# ..               ...       ...
# 28           (17155)  0.000500
# 91          (116808)  0.000500
# 58           (51878)  0.000500
# 97          (141619)  0.000500
# 126  (206362, 89805)  0.000500
#
# [127 rows x 2 columns]

# %% [markdown]
# # nvm

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# Assuming you have already created the merged_dict
# Convert the merged_dict to a list of lists (transactions)
transactions = list(total_dict.values())

# Initialize the TransactionEncoder
te = TransactionEncoder()
# Fit and transform the transactions using the TransactionEncoder
te_ary = te.fit(transactions).transform(transactions)
# Convert the transformed array back to a DataFrame
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm to calculate frequent itemsets 3
frequent_itemsets = apriori(df_encoded, min_support=0.001, use_colnames=True)

# Extract the item and its support value from the frequent itemsets DataFrame
frequent_items_with_support = frequent_itemsets[['itemsets', 'support']]

# Sort the frequent items by support in descending order
frequent_items_with_support = frequent_items_with_support.sort_values(by='support', ascending=False)

# Display the frequent items along with their support values (sorted by support)
frequent_items_with_support
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                itemsets   support
# 92                                              (39885)  0.004479
# 94                                              (42170)  0.003919
# 72                                              (29542)  0.003919
# 236                                            (118274)  0.003919
# 89                                              (39124)  0.003919
# ...                                                 ...       ...
# 1268                     (30225, 104057, 24029, 218783)  0.001120
# 1269                     (30225, 368786, 104057, 24029)  0.001120
# ...

# %%
import pandas as pd

# ... (Previous code up to 'frequent_items_with_support')

# Calculate the length of each itemset and add it as a new column 'length'
frequent_items_with_support['length'] = frequent_items_with_support['itemsets'].apply(lambda x: len(x))

# Calculate the mean and mode of the 'length' column
mean_length = frequent_items_with_support['length'].mean()
mode_length = frequent_items_with_support['length'].mode().iloc[0]

# Display the frequent items along with their support values and the calculated mean and mode of the length
print("Mean Length of Itemsets:", mean_length)
print("Mode Length of Itemsets:", mode_length)
frequent_items_with_support
# Out:
# Mean Length of Itemsets: 4.241833810888252
# Mode Length of Itemsets: 5
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                itemsets   support  length
# 92                                              (39885)  0.004479       1
# 94                                              (42170)  0.003919       1
# 72                                              (29542)  0.003919       1
# 236                                            (118274)  0.003919       1
# 89                                              (39124)  0.003919       1
# ...                                                 ...       ...     ...
# ...

# %%
import pandas as pd

# ... (Previous code up to 'frequent_items_with_support')

# Group the frequent itemsets by their lengths and calculate the count of itemsets for each length
itemsets_count_by_length = frequent_items_with_support.groupby('length').count()

# Rename the column to 'count'
itemsets_count_by_length.rename(columns={'itemsets': 'count'}, inplace=True)

# Display the itemsets count by length
itemsets_count_by_length
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         count  support
# length
# 1         433      433
# 2         269      269
# 3         465      465
# 4         674      674
# 5         707      707
# 6         535      535
# 7         284      284
# 8         100      100
# 9          21       21
# 10          2        2

# %%
import pandas as pd

# ... (Previous code up to 'itemsets_count_by_length')

# Calculate the product of length and count and create a new column 'length_times_count'
itemsets_count_by_length['length_times_count'] = itemsets_count_by_length['count'] * itemsets_count_by_length.index

# Display the updated DataFrame
print(itemsets_count_by_length)
# Out:
#         count  support  length_times_count
# length
# 1         433      433                 433
# 2         269      269                 538
# 3         465      465                1395
# 4         674      674                2696
# 5         707      707                3535
# 6         535      535                3210
# 7         284      284                1988
# 8         100      100                 800
# 9          21       21                 189
# 10          2        2                  20
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Calculate the sum of the 'length_times_count' column
sum_length_times_count = itemsets_count_by_length['length_times_count'].sum()

# Display the sum of length_times_count
print("Sum of length_times_count:", sum_length_times_count)
print('')
# Out:
# Sum of length_times_count: 14804
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# id1          5665
# id2          5665
# timestamp    5665
# action       5665
# dtype: int64
